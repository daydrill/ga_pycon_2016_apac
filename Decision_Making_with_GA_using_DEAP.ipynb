# %% [markdown]
# <hr style="border-color:#ff9900">
# ## _Practice 1 : _
# # Basic Genetic Algorithm
# <hr style="border-color:#ff9900">

# %% [markdown]
# ## Setting Things Up

# %%
import random
import numpy as np
from deap import algorithms, base, creator, tools

# %% [markdown]
# ### Creator
# - Meta-factory allowing the run-time creation of classes via both inheritance and composition.
# - Attributes, both data and functions, can be dynamically added to existing classes in order to create user-specific new types.
# - By using this, the creation of individuals and populations from any data structure ( list, set, dictionary, tree, etc… )

# %%
# Creates a new class named "FitnessMin" inheriting from "base.Fitness" with attrebute "weights=(-1.0,)"
creator.create("FitnessMin", base.Fitness, weights=(-1.0,)) # -1 -> minimum problem
creator.create("Individual", list, fitness=creator.FitnessMin)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %% [markdown]
# ### Toolbox
# - Container for the tools (operators) that the user wants to use.
# - Manually populated by the user with selected tools.

# %%
toolbox = base.Toolbox()

# %%
# Attribute generator 
toolbox.register("attr_bool", random.randint, 0, 100)

# %%
# Structure initializers
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, 5)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
toolbox.population(n=10)
# Out:
# [[55, 62, 0, 13, 26],
#  [86, 98, 49, 96, 7],
#  [87, 93, 67, 68, 13],
#  [100, 77, 75, 54, 40],
#  [74, 29, 32, 18, 68],
#  [10, 78, 21, 1, 54],
#  [18, 64, 63, 36, 55],
#  [91, 69, 35, 11, 52],
#  [66, 22, 72, 2, 75],
#  [99, 82, 4, 85, 4]]

# %% [markdown]
# ## The Evaluation Function

# %%
def sum_error(individual):
    return abs(100-sum(individual)),

# %%
# smaple individual
ind = toolbox.individual()
ind
# Out:
# [8, 47, 97, 35, 25]

# %%
sum_error(ind)
# Out:
# (112,)

# %% [markdown]
# ## The Genetic Operators
# - Operators are just like initializers, except that some are already implemented in the [tools](http://deap.readthedocs.io/en/master/api/tools.html#module-deap.tools) module.
# - __Once you’ve chosen the perfect ones, simply register them in the toolbox.__

# %%
toolbox.register("evaluate", sum_error)

# %%
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutUniformInt, low=0, up=100, indpb=0.2) # Independent probability  : for each attribute to be mutated.# low~up rondom int
toolbox.register("select", tools.selTournament, tournsize=3)

# %% [markdown]
# ## Evolving the Population

# %% [markdown]
# ### Creating the Population

# %%
pop = toolbox.population(n=100)
pop
# Out:
# [[53, 74, 78, 24, 47],
#  [56, 39, 69, 70, 95],
#  [95, 83, 20, 49, 96],
#  [51, 99, 92, 68, 61],
#  [64, 67, 15, 96, 28],
#  [94, 36, 2, 87, 97],
#  [11, 28, 70, 1, 63],
#  [41, 8, 29, 46, 26],
#  [49, 68, 53, 61, 2],
#  [16, 21, 8, 73, 1],
#  [58, 17, 95, 41, 7],
#  [42, 87, 33, 87, 38],
#  [55, 99, 61, 90, 98],
#  [61, 73, 24, 32, 34],
#  [65, 24, 50, 88, 57],
#  [95, 76, 11, 99, 54],
#  [50, 78, 84, 99, 27],
#  [23, 11, 99, 9, 90],
#  [14, 9, 28, 81, 22],
#  [54, 56, 49, 7, 59],
#  [96, 90, 63, 45, 27],
#  [26, 44, 73, 5, 53],
#  [71, 18, 45, 67, 41],
#  [12, 44, 25, 50, 91],
#  [74, 69, 8, 74, 32],
#  [79, 16, 65, 48, 6],
#  [91, 14, 90, 79, 22],
#  [68, 32, 80, 19, 42],
#  [32, 44, 41, 22, 68],
#  [96, 18, 26, 52, 18],
#  [16, 85, 83, 53, 50],
#  [44, 75, 13, 85, 76],
#  [36, 79, 58, 80, 7],
#  [88, 73, 75, 33, 81],
#  [16, 86, 68, 90, 11],
#  [65, 4, 20, 56, 29],
#  [91, 18, 18, 76, 23],
#  [75, 53, 0, 85, 98],
#  [89, 14, 13, 52, 46],
#  [68, 38, 87, 54, 79],
#  [23, 3, 27, 26, 44],
#  [95, 94, 28, 47, 61],
#  [69, 45, 56, 73, 92],
#  [86, 94, 0, 100, 83],
#  [5, 15, 82, 67, 80],
#  [94, 21, 84, 35, 92],
#  [34, 68, 94, 97, 23],
#  [45, 64, 21, 54, 97],
#  [85, 19, 34, 27, 71],
#  [47, 85, 36, 51, 40],
#  [77, 91, 17, 75, 4],
#  [58, 56, 47, 28, 85],
#  [94, 87, 78, 53, 0],
#  [47, 46, 95, 21, 19],
#  [29, 71, 21, 23, 2],
#  [46, 30, 64, 67, 0],
#  [70, 6, 29, 92, 56],
#  [62, 58, 26, 40, 93],
#  [18, 23, 84, 73, 30],
#  [87, 96, 12, 8, 92],
#  [31, 37, 73, 32, 77],
#  [75, 91, 79, 46, 35],
#  [27, 69, 63, 28, 92],
#  [15, 95, 59, 49, 98],
#  [54, 69, 76, 63, 60],
#  [24, 48, 73, 66, 71],
#  [3, 83, 25, 60, 3],
#  [51, 27, 25, 56, 49],
#  [99, 19, 34, 73, 8],
#  [56, 76, 74, 63, 96],
#  [36, 63, 6, 10, 33],
#  [53, 96, 90, 46, 10],
#  [44, 81, 6, 48, 45],
#  [95, 27, 19, 75, 22],
#  [93, 74, 22, 9, 19],
#  [55, 73, 29, 24, 45],
#  [52, 2, 26, 99, 64],
#  [44, 48, 29, 98, 17],
#  [51, 43, 64, 31, 35],
#  [36, 20, 9, 46, 65],
#  [93, 18, 93, 39, 52],
#  [37, 4, 72, 31, 33],
#  [48, 22, 43, 93, 61],
#  [8, 3, 14, 3, 85],
#  [45, 3, 77, 2, 21],
#  [51, 84, 49, 87, 86],
#  [43, 25, 88, 4, 56],
#  [62, 91, 76, 38, 80],
#  [100, 3, 18, 43, 72],
#  [61, 26, 10, 30, 100],
#  [85, 98, 88, 13, 52],
#  [17, 19, 55, 63, 44],
#  [67, 13, 86, 26, 91],
#  [6, 87, 61, 55, 37],
#  [42, 53, 87, 60, 96],
#  [73, 21, 67, 41, 29],
#  [32, 94, 19, 95, 8],
#  [47, 33, 12, 8, 57],
#  [37, 13, 68, 37, 47],
#  [59, 19, 49, 63, 48]]

# %% [markdown]
# ### The Appeal of Evolution

# %%
# Use of a HallOfFame in order to keep track of the best individual to appear in the evolution 
# (it keeps it even in the case it extinguishes)
hof = tools.HallOfFame(1)

# %%
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

# %%
# algorithms : contains useful implements some basic GA
pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=40, stats=stats, halloffame=hof, verbose=True)
# Out:
# gen	nevals	avg   	std    	min	max
# 0  	100   	155.44	62.2969	13 	303
# 1  	66    	106.61	48.8966	3  	233
# 2  	67    	63.54 	43.3275	1  	204
# 3  	53    	35.82 	25.9836	1  	141
# 4  	56    	31.2  	25.318 	1  	116
# 5  	69    	27.19 	30.481 	1  	227
# 6  	57    	21.18 	23.9509	1  	138
# 7  	59    	13.32 	17.9538	0  	72
# 8  	58    	12.98 	20.2455	0  	98
# 9  	48    	12.94 	22.1435	0  	106
# 10 	57    	6.35  	15.4502	0  	98
# 11 	62    	14.87 	28.8703	0  	161
# 12 	61    	13.47 	27.953 	0  	125
# 13 	62    	7.68  	16.7409	0  	81
# 14 	57    	11.18 	23.5535	0  	109
# 15 	60    	9.63  	21.4488	0  	102
# 16 	57    	11.65 	28.6846	0  	187
# 17 	59    	6.83  	17.1482	0  	108
# 18 	66    	8.46  	19.8194	0  	90
# 19 	52    	4.51  	19.8884	0  	159
# 20 	57    	10.36 	26.9008	0  	142
# 21 	68    	6.95  	17.993 	0  	103
# 22 	77    	6.39  	19.0294	0  	111
# 23 	61    	8.28  	22.1928	0  	97
# 24 	46    	10.04 	34.0538	0  	231
# 25 	62    	5.99  	20.0661	0  	119
# 26 	57    	8.4   	24.3955	0  	139
# 27 	57    	4.7   	16.0141	0  	103
# 28 	66    	4.21  	15.9175	0  	95
# 29 	54    	6.44  	25.3867	0  	220
# 30 	57    	5.64  	20.0731	0  	155
# 31 	62    	12.08 	29.1241	0  	136
# 32 	70    	10.59 	27.3942	0  	130
# 33 	48    	3.08  	11.9538	0  	89
# 34 	52    	8.71  	29.2514	0  	224
# 35 	66    	6.75  	25.4249	0  	155
# 36 	56    	7.25  	20.2457	0  	103
# 37 	64    	6.24  	19.161 	0  	100
# 38 	54    	3.38  	16.468 	0  	146
# 39 	56    	2.82  	16.0925	0  	141
# 40 	69    	3.24  	14.8446	0  	114

# %%
[sum(ind) for ind in pop]
# Out:
# [100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  163,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  98,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  103,
#  100,
#  100,
#  100,
#  100,
#  100,
#  113,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  157,
#  100,
#  214,
#  100,
#  100,
#  100,
#  100,
#  129,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  143,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100]

# %%
tools.selBest(pop, k=5)
# Out:
# [[0, 6, 7, 15, 18],
#  [0, 6, 7, 15, 18],
#  [6, 7, 15, 18, 13],
#  [6, 7, 15, 18, 13],
#  [0, 6, 7, 13, 18]]

# %% [markdown]
# <hr style="border-color:#ff9900">
# ## _Practice 2 : _
# # Find the Best Tour Route using NSGA-ii
# <hr style="border-color:#ff9900">

# %% [markdown]
# # Preparing Data for GA

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import numpy as np

# 거리계산
from math import radians, cos, sin, asin, sqrt 

# Geo data viz
import folium

# %%
df_spot = pd.read_csv("seoul_street.csv")

# %%
df_spot
# Out:
#          street_ko                                    street_en  \
# 0            남대문거리                        fishing-tackle street
# 1          왕십리곱창골목                     Wangsimni Gopchang Alley
# 2       남산공원북측순환도로                  The north side of Ring-Road
# 3             장충단길                             Jangchungdan-gil
# 4              초동길                                  Chodong-gil
# 5         신당동떡볶이골목                                Topokki alley
# 6              돌담길                                   Doldam-gil
# 7             명동거리                           Myeong-dong street
# 8         청계천헌책방거리  Cheonggye Stream secondhand bookshop street
# 9            필리핀거리                       The Philippines Street
# 10         북악산길산책로                                 Bugaksan-gil
# 11           청와대앞길                            Cheongwadaeap-gil
# 12       동대문생선구이골목                             Baked fish Alley
# 13         인사동문화마당                       Insadong Culture Plaza
# 14           대학로거리                             Daehak-ro street
# 15            삼청동길                       Samcheongdong-gil Road
# 16           경복궁뒷길             Gyeongbokgung Palace back street
# 17         북악산길산책로                                 Bugaksan-gil
# 18             계동길                                  Gyedong-gil
# 19          둘레길3구간                           Dulle-gil course 3
# 20        응암동감자탕골목             Yongam Pork Back-bone Stew Alley
# 21         불광동먹자골목                      Bulgwangdong food alley
# 22        연신내로데오거리                                 Rodeo Street
# 23            해맞이길                                  Haemaji-gil
# 24         용산감자탕거리             Yongsan Pork Back-bone Stew Road
# 25            경리단길                         Finance corps street
# 26           이태원거리                               Itaewon street
# 27            여의서로                                   Yeouiseoro
# 28        안양천제방벚꽃길                     Anyangcheon Beotkkot-gil
# 29         신길동홍어거리                                 Skate Street
# ..             ...                                          ...
# 45        서래마을카페거리                    Seorae Villag Cafe Street
# 46          신촌이대거리                          Sinchon Ewha Street
# 47         아현동웨딩거리             Ahyeon-dong Wedding Dress Street
# 48        연남동차이나타운                                    Chinatown
# 49          아현동전골목                            Ahyeon Coin Alley
# 50         홍대예술의거리                    Hongik Univ Street of Art
# 51         메타세콰이어길                             Metasequoia Road
# 52             현충로                                 Hyeonchungno
# 53         경희대파전골목                   Kyunghee Univ pajeon Alley
# 54             홍릉길                                Hongneung-gil
# 55         화랑로낙엽거리               Hwarangno fallen leaves street
# 56        가리봉로데오거리                                 Rodeo Street
# 57       가리봉동차이나타운                                    Chinatown
# 58          건대맛의거리                         Geondae taste Street
# 59         건대로데오거리                                 Rodeo Street
# 60             능동로                                  Neungdongno
# 61         봉천동먹자골목                    Bongcheon-dong food Alley
# 62       걷고싶은문화의거리           Pedestrian-Friendly Culture Street
# 63         관악디자인거리                      Gwanak-gu design street
# 64   한강자전거도로(강서지구)       Hangang River cycle lane(Gangseo Area)
# 65        둘레길순례길구간                            Sullye-gil course
# 66        천호동로데오거리                                 Cheonho-dong
# 67  한강자전거도로(광나루지구)     Hangang River cycle lane(Gwangnaru Area)
# 68         천호디자인거리                        Cheonho design street
# 69           당리순대국              Dangni Korean Blood Sausag Soup
# 70          병천토속순대                      Byeongcheon folk sundae
# 71         청담동명품거리                  Chengdam-dong luxury street
# 72            테헤란로                                   Teheran-ro
# 73            가로수길                             Garosu-gild Road
# 74         논현동포차골목                  Nonhyeondong cart bar Alley
#
#                    address      dong_ko               dong_en         lng  \
# 0            서울시 중구 회현동 일대          회현동         Hoehyeon-dong  126.977432
# 54        서울시 동대문구 청량리동 일대         청량리동    Cheongnyangni-dong  127.046390
# 55         서울시 노원구 공릉2동 일대         공릉2동       Gongneung2-dong  127.087693
# 56          서울시 금천구 가산동 일대          가산동            Gasan-dong  126.884235
# 57         서울시 구로구 가리봉동 일대         가리봉동         Garibong-dong  126.887307
# 58          서울시 광진구 화양동 일대          화양동          Hwayang-dong  127.072736
# 59         서울시 광진구 자양4동 일대         자양4동          Jayang1-dong  127.080215
# 60           서울시 광진구 능동 일대           능동            Neung-dong  127.082462
# 61          서울시 관악구 행운동 일대          행운동          Jungang-dong  126.948986
# 62          서울시 관악구 신림동 일대          신림동         Samseong-dong  126.934598
# 63         서울시 관악구 낙성대동 일대         낙성대동          Jungang-dong  126.948986
# 64         서울시 강서구 방화2동 일대         방화2동         Banghwa3-dong  126.813323
# 65          서울시 강북구 우이동 일대          우이동             Insu-dong  127.004600
# 66         서울시 강동구 천호3동 일대         천호3동         Cheonho2-dong  127.126679
# 67         서울시 강동구 암사2동 일대         암사2동            Amsa3-dong  127.130833
# 68         서울시 강동구 성내2동 일대         성내2동        Seongnae1-dong  127.128898
# 69         서울시 강동구 명일2동 일대         명일2동        Myeongil2-dong  127.149692
# 70           서울시 강동구 길동 일대           길동              Gil-dong  127.147047
# 71          서울시 강남구 청담동 일대          청담동        Cheongdam-dong  127.052378
# 72         서울시 강남구 역삼2동 일대         역삼2동         Yeoksam2-dong  127.038889
# 73          서울시 강남구 신사동 일대          신사동        Apgujeong-dong  127.029232
# 74         서울시 강남구 논현1동 일대         논현1동        Nonhyeon2-dong  127.031196
#
#           lat  score
# 0   37.558050     80
# 1   37.568610     68
# 2   37.561350     55
# 3   37.561386     87
# 4   37.566410      4
# 5   37.557255     41
# 6   37.564130     34
# 7   37.568059     97
# 8   37.561350     54
# 9   37.581990      3
# 10  37.617896     32
# 11  37.589673      3
# 12  37.573690     43
# 13  37.574403     97
# 14  37.577132     99
# 15  37.582810     65
# 16  37.578390     63
# 17  37.592346     56
# 18  37.582612     23
# 19  37.638680     16
# 20  37.592642      1
# 21  37.619201     21
# 22  37.620971     17
# 23  37.535397      7
# 24  37.531945      5
# 25  37.538994     99
# 26  37.538994     99
# 27  37.528313      8
# 28  37.523203     16
# 29  37.505977     14
# ..        ...    ...
# 45  37.504695     87
# 46  37.561111     92
# 47  37.563799     32
# 48  37.563108     22
# 49  37.554602     33
# 50  37.554241     99
# 51  37.571498     43
# 52  37.500688     26
# 53  37.588832     68
# 54  37.588198     23
# 55  37.630593     42
# 56  37.475038     32
# 57  37.482833     12
# 58  37.543322     84
# 59  37.531921     65
# 60  37.551050     24
# 61  37.482941     64
# 62  37.463202     72
# 63  37.482941     23
# 64  37.577337     53
# 65  37.637094     36
# 66  37.543179     65
# 67  37.557926     32
# 68  37.530483     56
# 69  37.548684     34
# 70  37.538560     66
# 71  37.525406     76
# 72  37.499866     43
# 73  37.523825     98
# 74  37.513636     88
#
# [75 rows x 8 columns]

# %% [markdown]
# ## Viz Data

# %%
m = folium.Map(location=[np.mean(df_spot.lat), np.mean(df_spot.lng)], zoom_start=11, tiles='Stamen Toner')
for index, row in df_spot.iterrows():
    popup_txt = "%s // Score : %s " % (row.street_en, row.score)
    folium.Marker([row.lat, row.lng], popup=popup_txt).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Applying Genetic Algorithm

# %% [markdown]
# ## Setting Things Up

# %%
import random
import numpy as np
from deap import algorithms, base, creator, tools

# %% [markdown]
# ### Creator

# %%
creator.create("FitnessMulti", base.Fitness, weights=(-1.0,1.0))
creator.create("Individual", list, fitness=creator.FitnessMulti)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMulti' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %% [markdown]
# ### Toolbox

# %%
toolbox = base.Toolbox()

# %%
# Attribute generator 
toolbox.register("index", np.random.choice, len(df_spot), 5, replace=False) # choose 5 spots

# %%
# Structure initializers
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.index)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
# sample individual -> just index of the data
ind = toolbox.individual()
ind
# Out:
# [68, 32, 48, 33, 18]

# %%
df_spot.ix[ind]
# Out:
#    street_ko                street_en          address dong_ko  \
# 68   천호디자인거리    Cheonho design street  서울시 강동구 성내2동 일대    성내2동
# 32   목동로데오거리    Mok-dong Rodeo Street  서울시 양천구 신정4동 일대    신정4동
# 48  연남동차이나타운                Chinatown   서울시 마포구 연남동 일대     연남동
# 33   청소년문화거리  Teenager Culture Street   서울시 양천구 목5동 일대     목5동
# 18       계동길              Gyedong-gil   서울시 종로구 가회동 일대     가회동
#
#            dong_en         lng        lat  score
# 68  Seongnae1-dong  127.128898  37.530483     56
# 32  Sinjeong6-dong  126.862987  37.516577     42
# 48    Yeonnam-dong  126.922346  37.563108     22
# 33       Mok5-dong  126.875894  37.536597      7
# 18      Gahoe-dong  126.984807  37.582612     23

# %% [markdown]
# ## The Evaluation Function
# - objective function 1. __total distance -> minimun__
# - objective function 2. __total score -> maximum__

# %%
def create_tour(individual):
    return [(df_spot.ix[i].lat, df_spot.ix[i].lng) for i in individual]

# %%
# convert index to geo data for get distance.
tour = create_tour(ind)
tour
# Out:
# [(37.530483386299998, 127.12889765700001),
#  (37.516577196999997, 126.86298654209999),
#  (37.563108312800004, 126.9223460779),
#  (37.536597301599997, 126.87589368530001),
#  (37.582612384000001, 126.9848066184)]

# %%
## Function for get a total distance of tour case
def total_distance(tour):
    tour_sum = sum(distance(tour[i], tour[i+1]) for i in range(len(tour)-1))
    return tour_sum

def distance(spot1, spot2):
    # convert decimal degrees to radians 
    lng1, lat1, lng2, lat2 = map(radians, [spot1[0], spot1[1], spot2[0], spot2[1]])
    
    RADIUS = 6371 # FAA approved globe radius in km
    
    dlng = lng2-lng1
    dlat = lat2-lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlng/2)**2
    c = 2 * asin(sqrt(a)) 
    dist = RADIUS * c
    return dist

# %%
# total distance of sample individual
total_distance(tour)
# Out:
# 54.83217558629738

# %%
def plot_tour(ind):
    tour = create_tour(ind)
    m = folium.Map(location=[np.mean(df_spot.lat), np.mean(df_spot.lng)], zoom_start=11) #, tiles='Stamen Toner')
    path=folium.PolyLine(locations=tour,weight=5)
    m.add_children(path)
    for i,loc in enumerate(ind):
        popup_txt = "%s // Score : %s " % (df_spot.ix[loc].street_en, df_spot.ix[loc].score)
        folium.Marker(tour[i], popup=popup_txt).add_to(m)
#         folium.Marker(tour[i], popup=df_spot.ix[loc].street_en).add_to(m)
    return m

# %%
# vizualize the tour
plot_tour(ind)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
def total_score(individual):
    return sum([df_spot.ix[i]['score'] for i in individual])

# %%
# total scores of the sample individual
total_score(ind)
# Out:
# 150

# %%
def eval_func(individual):
    
    # 1 total distance -> minimun
    t_dist = total_distance(create_tour(individual))
    
    # 2 total score -> maximum
    t_score = total_score(individual)
    
    # 3 penalty
    penalty = len(individual) - len(set(individual))
    t_dist += penalty*1000000
    t_score -= penalty*1000000
    
    return t_dist, t_score

# %%
# total scores of the sample individual
eval_func(ind)
# Out:
# (54.83217558629738, 150)

# %% [markdown]
# ## The Genetic Operators

# %%
toolbox.register("evaluate", eval_func)

# %%
toolbox.register("select", tools.selNSGA2)
toolbox.register("mate", tools.cxTwoPoint)
# tools.mutShuffleIndexes : Shuffle the attributes of the input individual and return the mutant.
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.8)

# %% [markdown]
# ## Evolving the Population

# %%
POP_SIZE = 100
MAX_GEN = 100
MUT_PROB = 0.2
CX_PROB = 0.8

# %% [markdown]
# ### Creating the Population

# %%
pop = toolbox.population(n=POP_SIZE)
pop
# Out:
# [[69, 26, 27, 37, 4],
#  [49, 47, 0, 30, 69],
#  [51, 30, 68, 52, 19],
#  [67, 73, 40, 23, 36],
#  [41, 52, 61, 65, 66],
#  [6, 64, 32, 50, 37],
#  [20, 22, 8, 53, 68],
#  [52, 44, 73, 16, 25],
#  [19, 21, 54, 60, 56],
#  [56, 33, 68, 21, 69],
#  [48, 25, 33, 52, 43],
#  [19, 22, 66, 4, 3],
#  [30, 38, 13, 45, 74],
#  [10, 70, 12, 49, 11],
#  [15, 27, 41, 36, 49],
#  [43, 35, 25, 46, 31],
#  [50, 26, 37, 10, 60],
#  [24, 15, 61, 6, 19],
#  [20, 15, 1, 13, 24],
#  [13, 46, 48, 66, 7],
#  [31, 18, 33, 42, 34],
#  [26, 5, 32, 44, 48],
#  [25, 27, 42, 44, 41],
#  [13, 72, 48, 66, 2],
#  [6, 15, 41, 11, 32],
#  [41, 57, 31, 14, 70],
#  [46, 6, 39, 22, 55],
#  [71, 58, 34, 29, 8],
#  [26, 66, 10, 42, 8],
#  [22, 50, 73, 3, 36],
#  [30, 5, 72, 37, 15],
#  [22, 53, 55, 60, 72],
#  [26, 21, 43, 32, 46],
#  [53, 50, 12, 64, 61],
#  [48, 55, 35, 67, 32],
#  [61, 10, 37, 49, 21],
#  [59, 73, 0, 46, 72],
#  [2, 52, 59, 19, 39],
#  [49, 54, 17, 16, 51],
#  [55, 36, 24, 27, 20],
#  [31, 37, 49, 43, 18],
#  [17, 49, 57, 42, 43],
#  [52, 3, 60, 25, 19],
#  [35, 22, 49, 55, 60],
#  [33, 28, 45, 67, 42],
#  [73, 21, 44, 70, 31],
#  [18, 40, 69, 71, 22],
#  [71, 28, 50, 12, 3],
#  [48, 53, 28, 68, 44],
#  [58, 24, 12, 30, 9],
#  [11, 58, 57, 66, 21],
#  [15, 64, 31, 18, 41],
#  [19, 54, 27, 43, 34],
#  [50, 69, 26, 74, 3],
#  [34, 21, 47, 11, 3],
#  [62, 10, 31, 39, 42],
#  [1, 67, 73, 32, 35],
#  [23, 0, 59, 18, 43],
#  [15, 49, 25, 13, 64],
#  [58, 14, 7, 17, 69],
#  [47, 24, 60, 8, 18],
#  [4, 56, 46, 39, 49],
#  [40, 16, 6, 62, 55],
#  [54, 44, 10, 12, 11],
#  [27, 62, 12, 40, 53],
#  [56, 67, 60, 23, 69],
#  [44, 11, 14, 46, 13],
#  [45, 46, 70, 16, 38],
#  [56, 62, 43, 37, 45],
#  [65, 7, 46, 69, 23],
#  [23, 43, 11, 47, 6],
#  [64, 28, 19, 51, 3],
#  [33, 56, 20, 4, 66],
#  [49, 6, 66, 42, 14],
#  [22, 58, 39, 46, 42],
#  [36, 16, 62, 0, 29],
#  [18, 29, 60, 6, 25],
#  [63, 59, 8, 50, 7],
#  [57, 23, 17, 7, 72],
#  [40, 20, 15, 69, 52],
#  [60, 47, 0, 34, 20],
#  [17, 22, 36, 67, 32],
#  [14, 49, 46, 71, 34],
#  [10, 14, 62, 17, 55],
#  [46, 18, 8, 44, 23],
#  [21, 36, 3, 4, 28],
#  [65, 19, 57, 69, 8],
#  [16, 56, 6, 55, 74],
#  [65, 16, 60, 37, 9],
#  [28, 27, 11, 48, 10],
#  [2, 26, 6, 37, 56],
#  [8, 14, 43, 22, 61],
#  [48, 37, 62, 27, 53],
#  [40, 34, 26, 68, 29],
#  [17, 18, 29, 0, 4],
#  [72, 7, 22, 59, 14],
#  [61, 38, 3, 58, 53],
#  [66, 55, 24, 17, 28],
#  [40, 18, 45, 35, 54],
#  [56, 15, 73, 67, 6]]

# %% [markdown]
# ### The Appeal of Evolution

# %%
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean, axis=0) 
stats.register("min", np.min, axis=0)
stats.register("max", np.max, axis=0)

# %%
# %%time 
result, log = algorithms.eaMuPlusLambda(pop, 
                                     toolbox, 
                                     mu=POP_SIZE, # The number of individuals to select for the next generation.
                                     lambda_= POP_SIZE, # The number of children to produce at each generation.
                                     cxpb= CX_PROB,
                                     mutpb= MUT_PROB, 
                                     stats= stats, 
                                     ngen= MAX_GEN,
                                     verbose= True)
# Out:
# gen	nevals	avg                          	min                        	max
# 0  	100   	[  40.33629387  232.26      ]	[ 15.91206094  79.        ]	[  81.80818368  407.        ]
# 1  	100   	[  30.86501113  268.24      ]	[  8.18597998  81.        ]	[  58.22683119  407.        ]
# 2  	100   	[  27.36648642  305.43      ]	[  8.18597998  81.        ]	[  52.41534391  449.        ]
# 3  	100   	[  24.60314749  338.07      ]	[   8.18597998  140.        ]	[  58.31144101  449.        ]
# 4  	100   	[  20.93000149  358.39      ]	[   8.18597998  140.        ]	[  50.50772293  451.        ]
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import HoverTool, ColumnDataSource
from bokeh import palettes
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7e6672f5-805d-4bb2-8a25-1da296535aca">Loading BokehJS ...</span>
#     </div>

# %%
def viz_front(fronts):
    TOOLS = "pan,wheel_zoom,box_zoom,reset,resize"
    hover = HoverTool(
            tooltips=[
                ("index", "$index"),
                ("(x,y)", "($x, $y)"),
                ("individual", "@ind"),
            ]
        )
    front_colors = []
    p = figure(plot_width=700, plot_height=700, tools=[TOOLS,hover], title="NSGAii Test")

    for i,inds in enumerate(fronts):
        par = [(ind, toolbox.evaluate(ind)) for ind in inds]
        source = ColumnDataSource(
                data=dict(
                    x= [p[1][0] for p in par],
                    y= [p[1][1] for p in par],
                    ind= [p[0] for p in par]
                )
            )
        p.circle('x', 'y', size=10, source=source, alpha=0.7, fill_color=palettes.YlGnBu9[i], legend='Front %s'%(i+1), line_color="#ffffff")
    show(p)

# %%
viz_front(fronts)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="eebec210-e358-4c50-9fdd-89b44c1ffb4d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eebec210-e358-4c50-9fdd-89b44c1ffb4d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eebec210-e358-4c50-9fdd-89b44c1ffb4d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c3834861-5e55-4769-9e0d-754c9b9964ab":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"},"tooltips":[["index","$index"],["(x,y)","($x, $y)"],["individual","@ind"]]},"id":"4a3da53b-9229-40d0-9e29-46c25e57ae86","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4a3da53b-9229-40d0-9e29-46c25e57ae86","type":"HoverTool"},{"id":"565d1117-8319-4388-afbb-9a0d3730ca30","type":"PanTool"},{"id":"da09338d-829a-4c7b-9b0a-47a848c75b72","type":"WheelZoomTool"},{"id":"25cce4ed-eb15-4231-928c-20b1f925db69","type":"BoxZoomTool"},{"id":"9e3fb7ba-21d0-4d1a-b30b-6c4602fbe55f","type":"ResetTool"},{"id":"b47c4f48-78fd-4cf0-81ae-1d2daf617354","type":"ResizeTool"}]},"id":"edb3a16a-1315-418f-a78a-575a262cdb0b","type":"Toolbar"},{"attributes":{"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"9c76171f-1ef9-4c14-aaaa-c3a29fb1bead","type":"BasicTicker"}},"id":"d8160e04-9678-42dc-86cb-629570cb3d3d","type":"Grid"},{"attributes":{"legends":[["Front 1",[{"id":"941f1489-42ec-46c3-8b4a-a50edea6d37f","type":"GlyphRenderer"}]]],"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"}},"id":"6991af8a-fa1d-4a36-9aa5-1a105813758a","type":"Legend"},{"attributes":{"formatter":{"id":"193e213d-bbcc-42fb-977c-1060e509402c","type":"BasicTickFormatter"},"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec938389-8af5-4c4a-9eb7-27eac7e82fb4","type":"BasicTicker"}},"id":"8955dc9b-691c-47a3-bcf8-88e0a3331298","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#081d58"},"line_alpha":{"value":0.7},"line_color":{"value":"#ffffff"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b42acbc-ffb9-4918-82e0-4a931e9092bc","type":"Circle"},{"attributes":{"data_source":{"id":"4d58060d-6c5d-491c-8761-136bee0ce08e","type":"ColumnDataSource"},"glyph":{"id":"4b42acbc-ffb9-4918-82e0-4a931e9092bc","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"02349e5d-3bde-4490-8611-42c5b4d8948c","type":"Circle"},"selection_glyph":null},"id":"941f1489-42ec-46c3-8b4a-a50edea6d37f","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"3d7893df-7ac1-4f3b-86bd-a0bea9aabb88","type":"BasicTickFormatter"},"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"9c76171f-1ef9-4c14-aaaa-c3a29fb1bead","type":"BasicTicker"}},"id":"e2283ff8-e6af-4f31-a373-cd8daf380e81","type":"LinearAxis"},{"attributes":{},"id":"9c76171f-1ef9-4c14-aaaa-c3a29fb1bead","type":"BasicTicker"},{"attributes":{"callback":null},"id":"6cc48e71-e1f2-4303-a0e5-491afb7c423a","type":"DataRange1d"},{"attributes":{},"id":"193e213d-bbcc-42fb-977c-1060e509402c","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"c2fe538d-dae2-422a-b451-509ebb0b804c","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"02349e5d-3bde-4490-8611-42c5b4d8948c","type":"Circle"},{"attributes":{},"id":"3d7893df-7ac1-4f3b-86bd-a0bea9aabb88","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"}},"id":"da09338d-829a-4c7b-9b0a-47a848c75b72","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"}},"id":"9e3fb7ba-21d0-4d1a-b30b-6c4602fbe55f","type":"ResetTool"},{"attributes":{"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure","type":"Plot"}},"id":"b47c4f48-78fd-4cf0-81ae-1d2daf617354","type":"ResizeTool"},{"attributes":{"plot":{"id":"e36ecd88-d8de-4f5c-80f0-c95d145a7cd1","subtype":"Figure ...

# %%
print(eval_func(fronts[0][99]))
# Out:
# (8.72512743679239, 492)

# %%
print(eval_func(fronts[0][0]))
# Out:
# (2.4247160726799675, 344)

# %%
plot_tour(fronts[0][99])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-807-3b90ea7c1e27> in <module>()
# ----> 1 plot_tour(fronts[0][99])
#
# <ipython-input-791-fc561204027e> in plot_tour(ind)
#       7     m.add_children(path)
#       8     for i,loc in enumerate(ind):
# ----> 9         folium.Marker(tour[i], popup=df_spot.ix[loc].adress).add_to(m)
#      10     return m
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2358                 return self[name]
#    2359             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2360                                  (type(self).__name__, name))
#    2361
#    2362     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'adress'

# %%
fronts[0][0]
# Out:
# [0, 6, 7, 16, 11]

# %%
df_spot.ix[fronts[0][99]]
# Out:
#    street_ko                  street_en           address dong_ko  \
# 73      가로수길           Garosu-gild Road    서울시 강남구 신사동 일대     신사동
# 14     대학로거리           Daehak-ro street    서울시 종로구 이화동 일대     이화동
# 25      경리단길       Finance corps street  서울시 용산구 이태원2동 일대   이태원2동
# 26     이태원거리             Itaewon street  서울시 용산구 이태원1동 일대   이태원1동
# 50   홍대예술의거리  Hongik Univ Street of Art    서울시 마포구 서교동 일대     서교동
#
#            dong_en         lng        lat  score
# 73  Apgujeong-dong  127.029232  37.523825     98
# 14       Ihwa-dong  127.005411  37.577132     99
# 25   Itaewon2-dong  126.991704  37.538994     99
# 26   Itaewon2-dong  126.991704  37.538994     99
# 50    Daheung-dong  126.937928  37.554241     99

# %%
df_spot
# Out:
#          street_ko                                    street_en  \
# 0            남대문거리                        fishing-tackle street
# 1          왕십리곱창골목                     Wangsimni Gopchang Alley
# 2       남산공원북측순환도로                  The north side of Ring-Road
